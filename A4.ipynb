# %% [markdown]
# <a href="https://colab.research.google.com/github/skipperr09/Army_Results/blob/main/A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("/content/Airline.csv")
df.head(10)
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (23) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0           1  2008     12           1          1      NaN        1000
# 1           2  2008     12           1          1      NaN        1000
# 2           3  2008     12           1          1      NaN        1000
# 3           4  2008     12           1          1      NaN        1000
# 4           5  2008     12           1          1      NaN        1000
# 5           6  2008     12           1          1      NaN        1005
# 6           7  2008     12           1          1      NaN        1015
# 7           8  2008     12           1          1      NaN        1020
# 8           9  2008     12           1          1      NaN        1029
# ...

# %%
df_null = df.columns[df.isna().any()]
print(df_null)
# Out:
# Index(['DepTime', 'ArrTime', 'TailNum', 'ActualElapsedTime', 'AirTime',
#        'ArrDelay', 'DepDelay', 'TaxiIn', 'TaxiOut', 'CancellationCode',
#        'CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay',
#        'LateAircraftDelay'],
#       dtype='object')

# %%
new_df = df.dropna(axis = 1);
new_df.head(10)
# Out:
#    Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  CRSDepTime  CRSArrTime  \
# 0           1  2008     12           1          1        1000        1100
# 1           2  2008     12           1          1        1000        1110
# 2           3  2008     12           1          1        1000        1125
# 3           4  2008     12           1          1        1000        1227
# 4           5  2008     12           1          1        1000        1227
# 5           6  2008     12           1          1        1005        1055
# 6           7  2008     12           1          1        1015        1145
# 7           8  2008     12           1          1        1020        1255
# 8           9  2008     12           1          1        1029        1112
# 9          10  2008     12           1          1        1030        1201
#
#   UniqueCarrier  FlightNum  CRSElapsedTime Origin Dest  Distance  Cancelled  \
# 0            WN         16              60    HOU  DAL       239          1
# ...

# %%
import numpy as np

sm_df = pd.DataFrame(df["DayofMonth"]);
sm_df["Value"] = 1
sm_df.head()
# Out:
#    DayofMonth  Value
# 0           1      1
# 1           1      1
# 2           1      1
# 3           1      1
# 4           1      1

# %%
per = (df[df["DayofMonth"]== 12])
print(per.shape)
# Out:
# (2764, 30)

# %%
grouped_data =  sm_df.groupby("DayofMonth").sum();
grouped_data.head(13)
# Out:
#             Value
# DayofMonth
# 1            3444
# 2            2645
# 3            2737
# 4            2678
# 5            2715
# 6            2022
# 7            1870
# 8            2820
# 9            2937
# 10           3060
# 11           3094
# 12           2764
# 13           1803

# %%
x = sm_df["DayofMonth"]
y = grouped_data["Value"]
fig, ax = plt.subplots(figsize=(15,10))
plt.plot(y, marker = "o", c="g")
plt.title("The total no. of flights that are running in each of day")
plt.ylabel("Number of Flights")
plt.xlabel("Days of Month")
plt.show()

# %%
df_p = (df[df["DayofMonth"] ==1])
print(df_p["Distance"])
group = df_p.groupby("DayofMonth").sum()
print(group["Distance"])
# Out:
# 0        239
# 1        185
# 2        417
# 3        403
# 4        235
#         ...
# 45941    446
# 45942    235
# 45943    130
# 45944    353
# 45945    174
# Name: Distance, Length: 3444, dtype: int64
# DayofMonth
# 1    1946469
# Name: Distance, dtype: int64

# %% [markdown]
# To check the skewness of the distance traveled by airlines each day using a line chart, you would first need to calculate the skewness of the data. Skewness is a statistical measure that describes the asymmetry of a distribution around its mean. There are several methods to calculate skewness, including the Pearson's moment coefficient of skewness and the sample skewness.
#
# Once you have calculated the skewness for each day, you can create a line chart to visualize how the skewness changes over time. On the x-axis, you would plot the dates, and on the y-axis, you would plot the skewness values. Connecting the skewness values for each date with a line would give you a visual representation of how the skewness changes over time.
#
# It's important to note that while this line chart would give you a visual representation of the skewness, it is not a conventional use of a line chart, as skewness is not a plotted data series, but a summary statistic.
#
# Additionally, if you want to visualize the distance traveled by airlines on each day, you can create a separate line chart with the dates on the x-axis and the distance traveled on the y-axis. This would give you a visual representation of the changes in the distance traveled over time.

# %% [markdown]
# I'm sorry, but as a text-based AI language model, I do not have the capability to create visual charts. I can only provide information and text-based responses.
#
# To check the skewness of the distance traveled by airlines each day, you would need to perform a statistical analysis of the data. Skewness is a measure of the asymmetry of a probability distribution about its mean. A positive skewness indicates that more weight is given to the right tail of the distribution, meaning that there are more outliers in the higher end of the data. A negative skewness indicates that more weight is given to the left tail of the distribution, meaning that there are more outliers in the lower end of the data.
#
# To calculate the skewness, you would need to use a skewness formula on the data set of distance traveled by airlines each day. There are several methods to calculate skewness, including the Pearson's moment coefficient of skewness and the sample skewness.
#
# Once you have calculated the skewness, you can then interpret the result to determine whether the data is positively skewed, negatively skewed, or approximately symmetrical. Depending on the skewness value, you may want to adjust or transform the data to make it more symmetrical before creating a line chart to visualize the data.bold text
